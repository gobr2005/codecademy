# %% [markdown]
# # Life Expectancy and GDP Project

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Step 1
#
# Project Scoop and load data

# %%
data = pd.read_csv('all_data.csv')
print(data)
print(data.count())
print(type(data))
# Out:
#      Country  Year  Life expectancy at birth (years)           GDP
# 0      Chile  2000                              77.3  7.786093e+10
# 1      Chile  2001                              77.3  7.097992e+10
# 2      Chile  2002                              77.8  6.973681e+10
# 3      Chile  2003                              77.9  7.564346e+10
# 4      Chile  2004                              78.0  9.921039e+10
# ..       ...   ...                               ...           ...
# 91  Zimbabwe  2011                              54.9  1.209845e+10
# 92  Zimbabwe  2012                              56.6  1.424249e+10
# 93  Zimbabwe  2013                              58.0  1.545177e+10
# 94  Zimbabwe  2014                              59.2  1.589105e+10
# 95  Zimbabwe  2015                              60.7  1.630467e+10
#
# [96 rows x 4 columns]
# Country                             96
# Year                                96
# Life expectancy at birth (years)    96
# ...

# %%
#Find unique year values for X Ticks Label
years=data['Year'].unique()
print(len(years))
plt.figure(figsize=[15,10])
ax1=plt.subplot()
sns.lineplot(x='Year', y='Life expectancy at birth (years)', data=data, hue='Country')
ax1.set_xticks(range(2000,2016))
ax1.set_xticklabels(years)
plt.savefig('line-chart_Life-Expectancy.png', facecolor='white')
plt.show()
plt.clf()
# Out:
# 16

# %%
plt.figure(figsize=[15,10])
ax1=plt.subplot()
sns.lineplot(x='Year', y='GDP', hue='Country', data=data)
plt.title('GDP per Country from 2000-2015')
ax1.set_xticks(range(2000,2016))
ax1.set_xticklabels(years)
plt.savefig('line-chart-GDP.png', facecolor='white')
plt.show()
plt.clf()

# %%
fig, ax = plt.subplots(1, 2, sharey=True, figsize=(15, 5))
#Violin Plot looking at country by Life Expectancy
ax[0] = plt.subplot(1,2,1)
ax[0] = sns.violinplot(data=data, y='Country',x='Life expectancy at birth (years)', scale="width")
plt.title("Life Expectancy at Birth per Country")

#Violin Plot looking at country by GDP
ax[1] = plt.subplot(1,2,2)
ax[1] = sns.violinplot(data=data, y='Country',x='GDP', scale="width")
plt.title("GDP per Country")
plt.savefig('violin_plot-life_expecy_gdp.png', facecolor='white')
plt.show()

# %%
plt.figure(figsize=[20,10])
ax1=plt.subplot()
sns.scatterplot(y='GDP',x="Life expectancy at birth (years)",data=data)
plt.title('Life Expectency according to GDP')
plt.savefig('scatterplot_GDP_life-expect.png')
plt.show()
